# %% [markdown]
# <a href="https://colab.research.google.com/github/simonoconnor2022/UCD-Upload-Practice-/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Upload csv file of Irish Attractions from laptop

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-537fd3a5-5505-4e01-a034-8ae05aa51f69" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-537fd3a5-5505-4e01-a034-8ae05aa51f69">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Attractions (1).csv to Attractions (1).csv

# %%
#import pandas

# %%
import pandas as pd

# %%
#write code inorder to read the uploaded Attractions (1) file

# %%
#Create Data Frame with relevevant headers

# %%
path = "Attractions (1).csv"

df = pd.read_csv(path)

df #displays dataframe
# Out:
#                                         Name  \
# 0            Ireland Writing Retreat Donegal
# 1                              Swords Castle
# 2                           Kilbolane Castle
# 3                              Spanish Point
# 4                              Dunloe Castle
# ..                                       ...
# 539  Macroom Buffalo Farm with O'Tuama Tours
# 540             The Back Lane Pop Up Gallery
# 541                          Ferns Cathedral
# 542                                The Spire
# 543                          Courtown  Beach
#
#                                                    Url         Telephone  \
# 0                https://www.irelandwritingretreat.com       3.53833E+11
# 1                         https://swordscastle.events/  +353(0)1840 0891
# 2    https://visitballyhoura.com/explore/kilbolane-...        3536391300
# 3                                                  NaN               NaN
# ...

# %%
# Understand the data that has been uploaded

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 544 entries, 0 to 543
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             544 non-null    object
#  1   Url              398 non-null    object
#  2   Telephone        342 non-null    object
#  3   Longitude        544 non-null    float64
#  4   Latitude         544 non-null    float64
#  5   AddressRegion    540 non-null    object
#  6   AddressLocality  384 non-null    object
#  7   AddressCountry   542 non-null    object
#  8   Tags             544 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 38.4+ KB

# %%
import numpy as np

# %%
#Rename Head of Column from Name to 'Tourist Attraction'

# %%
new_name = {'Name': 'Tourist Attraction'}

# %%
df.rename(columns = new_name)
# Out:
#                           Tourist Attraction  \
# 0            Ireland Writing Retreat Donegal
# 1                              Swords Castle
# 2                           Kilbolane Castle
# 3                              Spanish Point
# 4                              Dunloe Castle
# ..                                       ...
# 539  Macroom Buffalo Farm with O'Tuama Tours
# 540             The Back Lane Pop Up Gallery
# 541                          Ferns Cathedral
# 542                                The Spire
# 543                          Courtown  Beach
#
#                                                    Url         Telephone  \
# 0                https://www.irelandwritingretreat.com       3.53833E+11
# 1                         https://swordscastle.events/  +353(0)1840 0891
# 2    https://visitballyhoura.com/explore/kilbolane-...        3536391300
# 3                                                  NaN               NaN
# ...

# %%
#After some consideration, rename Address Region to County

# %%
new_name = {'AddressRegion': 'County'}

# %%
df.rename(columns = new_name)
# Out:
#                                         Name  \
# 0            Ireland Writing Retreat Donegal
# 1                              Swords Castle
# 2                           Kilbolane Castle
# 3                              Spanish Point
# 4                              Dunloe Castle
# ..                                       ...
# 539  Macroom Buffalo Farm with O'Tuama Tours
# 540             The Back Lane Pop Up Gallery
# 541                          Ferns Cathedral
# 542                                The Spire
# 543                          Courtown  Beach
#
#                                                    Url         Telephone  \
# 0                https://www.irelandwritingretreat.com       3.53833E+11
# 1                         https://swordscastle.events/  +353(0)1840 0891
# 2    https://visitballyhoura.com/explore/kilbolane-...        3536391300
# 3                                                  NaN               NaN
# ...
